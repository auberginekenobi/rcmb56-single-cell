# %%
## What is the distribution of z-scores?
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import scipy.stats
import sys

import matplotlib as mpl
mpl.rcParams['font.family'] = 'Arial'
mpl.rcParams['font.size'] = 7
plt.rcParams["figure.figsize"] = (2,2)
plt.rcParams["figure.dpi"] = 300
plt.rcParams['svg.fonttype'] = 'none'

sys.path.append("/mnt/c/Users/ochapman/Documents/Mesirov/scRNA+ATAC/src")
from SingleCellExperiment import *

# %%
pdx = rcmb56pdx().get_qc_pass_cells()

# %%
# ecDNA1 z-scores
# looks like a zero-inflated gamma, or a mixture of a bunch of gaussians...
df = pdx[['ecDNA1_z-score','ecDNA2_z-score','ecDNA3_z-score']]
ax=sns.histplot(df['ecDNA1_z-score'],binwidth=.5)
ax.set(xlim=(0, 30))
# Out:
# [(0.0, 30.0)]

# %%
# ecDNA3 z-scores
# looks like a zero-inflated gamma
df = pdx[['ecDNA1_z-score','ecDNA2_z-score','ecDNA3_z-score']]
ax=sns.histplot(df['ecDNA3_z-score'],binwidth=0.1)
ax.set(xlim=(0, 4))

# %%
# a zero-inflated gamma
#import statsmodels.discrete.count_model
#model = statsmodels.discrete.count_model.ZeroInflatedNegativeBinomialP
from scipy.stats import gamma
fig, ax = plt.subplots(1, 1)
a=1.8
x = np.linspace(0, 30, 100)
rv = gamma(a,scale=7)
ax.plot(x, rv.pdf(x), 'k-', lw=2, label='frozen pdf')

# %%
np.arange(nbinom.ppf(0.01, n, p))
# Out:
# array([0., 1., 2., 3.])

# %%
(gamma.ppf(0.01, a))
gamma.ppf(0.99, a)
np.linspace(gamma.ppf(0.01, a),
                gamma.ppf(0.99, a), 100)
# Out:
# array([0.14855474, 0.21410825, 0.27966176, 0.34521527, 0.41076877,
#        0.47632228, 0.54187579, 0.6074293 , 0.67298281, 0.73853632,
#        0.80408982, 0.86964333, 0.93519684, 1.00075035, 1.06630386,
#        1.13185737, 1.19741087, 1.26296438, 1.32851789, 1.3940714 ,
#        1.45962491, 1.52517842, 1.59073192, 1.65628543, 1.72183894,
#        1.78739245, 1.85294596, 1.91849947, 1.98405297, 2.04960648,
#        2.11515999, 2.1807135 , 2.24626701, 2.31182052, 2.37737402,
#        2.44292753, 2.50848104, 2.57403455, 2.63958806, 2.70514157,
#        2.77069507, 2.83624858, 2.90180209, 2.9673556 , 3.03290911,
#        3.09846262, 3.16401612, 3.22956963, 3.29512314, 3.36067665,
#        3.42623016, 3.49178367, 3.55733718, 3.62289068, 3.68844419,
#        3.7539977 , 3.81955121, 3.88510472, 3.95065823, 4.01621173,
#        4.08176524, 4.14731875, 4.21287226, 4.27842577, 4.34397928,
#        4.40953278, 4.47508629, 4.5406398 , 4.60619331, 4.67174682,
#        4.73730033, 4.80285383, 4.86840734, 4.93396085, 4.99951436,
#        5.06506787, 5.13062138, 5.19617488, 5.26172839, 5.3272819 ,
#        5.39283541, 5.45838892, 5.52394243, 5.58949593, 5.65504944,
#        5.72060295, 5.78615646, 5.85170997, 5.91726348, 5.98281698,
#        6.04837049, 6.113924  , 6.17947751, 6.24503102, 6.31058453,
#        6.37613803, 6.44169154, 6.50724505, 6.57279856, 6.63835207])
