# %%
library(Seurat)
# Out:
# Attaching SeuratObject

# %%
ht_file <- "rcmb56-ht_seuratobj.rds"
pdx_file <- "rcmb56-pdx_seuratobj.rds"
seuratobj <- readRDS(ht_file)

# %%
seuratobj
# Out:
# Loading required package: Signac
# An object of class Seurat
# 140455 features across 2986 samples within 3 assays
# Active assay: RNA (36601 features, 0 variable features)
#  2 other assays present: ATAC, SCT
#  5 dimensional reductions calculated: pca, umap.rna, lsi, umap.atac, wnn.umap

# %%
#png("rcmb56-ht_wnn-clusters.png")
DimPlot(seuratobj, reduction = "wnn.umap")
#dev.off()
# Out:
# plot without title

# %%
dev.on()
# Out:
# Error in dev.on(): could not find function "dev.on"
# Traceback:
