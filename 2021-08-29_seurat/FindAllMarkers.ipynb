# %%
library(dplyr)
library(ggplot2)
library(EnsDb.Hsapiens.v86)
library(Seurat)
library(Signac)
library(repr)
library(limma)
# Out:
# Error in library(limma): there is no package called 'limma'
# Traceback:
#
# 1. library(limma)

# %%
sample_name <- "rcmb56-ht"
#sample_name <- "rcmb56-pdx"

rds <- paste(sample_name,"_seuratobj.rds",sep="")
seuratobj <- readRDS(rds)
seuratobj
# Out:
# Loading required package: SeuratObject
#
# Loading required package: Signac
# An object of class Seurat
# 140599 features across 3591 samples within 3 assays
# Active assay: ATAC (83271 features, 83271 variable features)
#  2 other assays present: RNA, SCT
#  5 dimensional reductions calculated: pca, umap.rna, lsi, umap.atac, wnn.umap

# %%
# Find differential genes
DefaultAssay(seuratobj) <- "RNA"
markers <- FindAllMarkers(seuratobj)
# Out:
# Calculating cluster 0
#
# Calculating cluster 1
#
# Calculating cluster 2
#
# Calculating cluster 3
#
# Calculating cluster 4
#
# Calculating cluster 5
#
# Calculating cluster 6
#
# Calculating cluster 7
#
# Calculating cluster 8
#
# Calculating cluster 9
#
# Calculating cluster 10
#
# Calculating cluster 11
#
# Calculating cluster 12

# %%
markers
# Out:
#             p_val        avg_log2FC   pct.1 pct.2 p_val_adj    cluster
# MT-ATP6     7.392837e-58  -15.1766612 0.070 0.377 2.705852e-53 0
# MT-CO3      1.339959e-52  -31.4113769 0.129 0.415 4.904383e-48 0
# MT-ND4      1.157092e-49  -17.0656943 0.087 0.365 4.235073e-45 0
# MT-CO2      4.413787e-47  -28.4683164 0.128 0.396 1.615490e-42 0
# MT-ND3      4.918691e-47  -21.4710756 0.081 0.349 1.800290e-42 0
# MT-ND1      2.148956e-44  -13.7879777 0.099 0.357 7.865396e-40 0
# MT-CYB      1.447199e-41  -10.5032403 0.086 0.334 5.296893e-37 0
# MT-ND2      2.620031e-41  -10.8319598 0.080 0.327 9.589574e-37 0
# PLCG2       2.760739e-38 -551.8961463 0.670 0.765 1.010458e-33 0
# LINC00632   1.045835e-30  -69.6262350 0.575 0.706 3.827861e-26 0
# CSMD3       1.241594e-27  -34.6548155 0.014 0.176 4.544359e-23 0
# MT-ND5      1.364591e-26   -1.4742312 0.035 0.204 4.994540e-22 0
# MT-CO1      2.891103e-25  -16.7375956 0.146 0.333 1.058172e-20 0
# ELMO1       1.518998e-24  -61.5346763 0.101 0.283 5.559684e-20 0
# AL627171.2  2.630267e-24   -8.6634248 0.029 0.182 9.627039e-20 0
# PHACTR1     6.674705e-24  -24.3419918 0.165 0.354 2.443009e-19 0
# AKAP6       4.242328e-22  -83.6336808 0.380 0.537 1.552735e-17 0
# BOC.5       0.009902412  -89.1974900  0.000 0.125 1            12
# ETNK1.7     0.009916114  -16.2684396  0.319 0.194 1            12
# ZNF714.6    0.009926498   -1.4582275  0.106 0.271 1            12
# CRLS1       0.009933548    0.4393287  0.191 0.084 1            12
# LINC01184.6 0.009974593    3.0283769  0.128 0.323 1            12
# SLC44A3.6   0.009975891  -63.2294631  0.000 0.124 1            12
# CRTC3.2     0.009985447   -2.3941043  0.128 0.293 1            12
# NSG2.3      0.009992750   -9.8100383  0.021 0.158 1            12
# LURAP1L.7   0.009993231   -1.8794560  0.021 0.158 1            12
#             gene
# MT-ATP6     MT-ATP6
# MT-CO3      MT-CO3
# MT-ND4      MT-ND4
# MT-CO2      MT-CO2
# MT-ND3      MT-ND3
# MT-ND1      MT-ND1
# MT-CYB      MT-CYB
# MT-ND2      MT-ND2
# PLCG2       PLCG2
# LINC00632   LINC00632
# CSMD3       CSMD3
# MT-ND5      MT-ND5
# MT-CO1      MT-CO1
# ELMO1       ELMO1
# AL627171.2  AL627171.2
# PHACTR1     PHACTR1
# AKAP6       AKAP6
# NLGN1       NLGN1
# MT-ATP8     MT-ATP8
# TMEM108     TMEM108
# EXOC4       EXOC4
# MTRNR2L12   MTRNR2L12
# SRPK2       SRPK2
# EEF1A1      EEF1A1
# DANT2       DANT2
# MKLN1       MKLN1
# NRG1        NRG1
# PTPRK       PTPRK
# ERVMER61-1  ERVMER61-1
# AUTS2       AUTS2
# ⋮           ⋮
# ZNF787      ZNF787
# LIMCH1.10   LIMCH1
# FUBP1.5     FUBP1
# GAK.4       GAK
# HIP1.8      HIP1
# GALNT7.8    GALNT7
# SEC11A.3    SEC11A
# RPRD2.5     RPRD2
# TPRG1.1     TPRG1
# ADAM19.5    ADAM19
# ZNFX1.2     ZNFX1
# C2CD5.7     C2CD5
# GTF2F2.1    GTF2F2
# SFSWAP.3    SFSWAP
# VPS37C      VPS37C
# SHTN1.4     SHTN1
# ATL1.3      ATL1
# ZFY.4       ZFY
# ZFHX2-AS1.3 ZFHX2-AS1
# TMEM165.5   TMEM165
# CSMD2.8     CSMD2
# BOC.5       BOC
# ETNK1.7     ETNK1
# ZNF714.6    ZNF714
# CRLS1       CRLS1
# LINC01184.6 LINC01184
# SLC44A3.6   SLC44A3
# CRTC3.2     CRTC3
# NSG2.3      NSG2
# LURAP1L.7   LURAP1L

# %%
markers['',]
# Out:
#    p_val avg_log2FC pct.1 pct.2 p_val_adj cluster gene
# NA NA    NA         NA    NA    NA        NA      NA

# %%
write.table(markers,file = 'rcmb56-ht_FindAllMarkers.tsv',sep='\t')
